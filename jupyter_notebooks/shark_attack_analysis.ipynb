# %% [markdown]
# # **Shark Attack Data Analysis**

# %% [markdown]
# # Exploring Global Shark-Human Interaction Patterns
#
# ### Data Analytics Capstone Project
#
# **Author:** Shazia
#
# **Course:** Diploma in Data Analytics & Artificial Intelligence
#
# **Tools Used:** Python, Pandas, Matplotlib, Seaborn, Power BI
#
# **Dataset:** Global Shark Attack Dataset (Kaggle)

# %% [markdown]
# This notebook analyses global shark attack incident data to identify patterns in shark–human interactions across time, geography, and human activities.
#
# The analysis demonstrates the full data analytics workflow, including data preparation, data cleaning, exploratory analysis, statistical testing, and visualisation. Insights generated in this notebook will support the development of an interactive Power BI dashboard.

# %% [markdown]
# ---

# %% [markdown]
# ## Project Overview
#
# Interactions between humans and marine wildlife have increased significantly in recent decades due to the growth of coastal tourism and recreational water activities. Among marine animals, sharks are frequently portrayed as dangerous predators due to media coverage of shark attack incidents.
#
# However, research indicates that shark attacks on humans are extremely rare relative to the number of people entering the ocean each year (Neff & Hueter, 2013). At the same time, many shark species are threatened due to overfishing and habitat degradation (Dulvy et al., 2014).
#
# This project analyses global shark attack incident data to identify patterns in shark–human interactions across time, geography, and human activity. Using Python-based data analysis and interactive visualisation, the project communicates insights through an interactive dashboard developed using Microsoft Power BI.
#
# The project demonstrates the complete data analytics workflow, including data preparation, exploratory analysis, hypothesis testing, and dashboard visualisation.
#
#
# ## Project Narrative
#
# Sharks play a crucial role in marine ecosystems as apex predators that regulate marine food chains and contribute to ecosystem stability. Despite their ecological importance, sharks are often perceived negatively due to sensationalised media coverage of shark attacks.
#
# Media narratives frequently portray sharks as aggressive predators, which can exaggerate public perceptions of risk (Neff & Hueter, 2013). In reality, shark attacks are rare events compared with the millions of people who participate in ocean activities each year.
#
# By analysing shark attack datasets, it is possible to identify patterns in geographic distribution, human activities associated with incidents, and temporal trends. Data visualisation allows these insights to be communicated in a clear and accessible way to both technical and non-technical audiences.
#
#
# ## Project Motivation
#
# The motivation for this project is to demonstrate how data analytics can be applied to wildlife incident data while communicating findings responsibly.
#
# Shark attack data provides a useful case study because it illustrates how statistical evidence can differ from public perception. By analysing shark incidents and presenting findings through clear visualisations, the project aims to encourage evidence-based understanding of shark–human interactions.
#
#
# ## Business Case
#
# Wildlife incident datasets can be complex and difficult for non-specialists to interpret. Interactive dashboards allow large datasets to be explored visually, enabling users to identify patterns quickly and easily.
#
# This project develops an interactive dashboard that enables users to explore shark attack incidents across time, geography, species involvement, and human activities, helping users identify patterns and trends within the dataset.
#
#
# ## Target Audience
#
# The dashboard is designed for both technical and non-technical users.
#
# Technical audiences:
#  - data analysts
#  - marine researchers
#  - environmental scientists
#
# Non-technical audiences:
#  - marine conservation organisations
#  - ocean safety organisations
#  - members of the public interested in marine wildlife
#
#
# ## Research Questions
#
# The analysis aims to investigate patterns in global shark attack incidents by addressing the following research questions:
#
# 1. How does the frequency of shark attack incidents vary between countries?
#
# 2. Is there an association between the type of human activity being performed and the fatality outcome of a shark attack?
#
# 3. What proportion of recorded shark attacks result in fatal versus non-fatal outcomes?
#
# 4. How have recorded shark attack incidents changed over time?
#
#
# ## Hypotheses
#
# To investigate patterns in shark attack incidents, the following statistically testable hypotheses are proposed.
#
# ### Hypothesis 1 — Country Distribution
#
# H0₁: Shark attack frequency is independent of the country in which the incident occurred.
#
# H1₁: Shark attack frequency varies significantly between countries.
#
# Test Method:
# Chi-square test of independence.
#
#
# ### Hypothesis 2 — Activity and Fatality Outcome
#
# H0₂: Fatality outcome is independent of the activity being performed during the shark attack incident.
#
# H1₂: Fatality outcome is associated with the activity being performed.
#
# Test Method:
# Chi-square test of independence.
#
#
# ### Hypothesis 3 — Fatal vs Non-Fatal Proportion
#
# H0₃: The proportion of fatal shark attacks is equal to the proportion of non-fatal shark attacks.
#
# H1₃: The proportion of non-fatal shark attacks is greater than the proportion of fatal shark attacks.
#
# Test Method:
# Proportion comparison using descriptive statistics.
#
#
# ### Hypothesis 4 — Temporal Trends
#
# H0₄: The number of recorded shark attack incidents has remained constant over time.
#
# H1₄: The number of recorded shark attack incidents has increased over time.
#
# Test Method:
# Trend analysis using descriptive statistics and visual inspection.
#
#
# ## Statistical Methods
#
# The analysis will apply a combination of descriptive and inferential statistical methods to explore patterns within the dataset.
#
# The following techniques will be used:
#  -  Descriptive statistics to summarise the distribution of shark attacks across time, location, and activity types.
#  - Cross-tabulation to examine relationships between categorical variables such as activity type and fatality outcome.
#  - Chi-square tests of independence to determine whether variables such as country and activity type are associated with shark attack outcomes.
#  - Trend analysis to evaluate changes in shark attack frequency over time.
#
# These methods allow the analysis to move beyond simple visual exploration and provide statistical evidence for observed patterns within the dataset.
#
#
# ## Objectives
#
# Project objectives:
# - Analyse global shark attack incident data.
# - Identify patterns in shark–human interactions.
# - Explore geographic and behavioural factors associated with shark attacks.
# - Develop an interactive dashboard communicating insights clearly.
# - Evaluate ethical considerations related to wildlife incident data.
# - Document the full data analytics project lifecycle.
#
# Notebook objectives:
# - Load and inspect the global shark attacks dataset.
# - Clean and anonymise the dataset by removing personally identifiable information.
# - Explore patterns in shark incidents across time, geography, and human activities.
# - Analyse the relationship between activity type and fatality outcomes.
# - Generate insights that will be used to build an interactive Power BI dashboard.
#
#
# ## Inputs
#
# - data/raw/shark_attacks.csv – raw shark attack dataset obtained from Kaggle.
# - Python libraries including pandas, numpy, matplotlib, seaborn, and plotly.
# - Jupyter Notebook environment for data analysis and visualisation.
#
#
# ## Outputs
#
# - Cleaned dataset for analysis.
# - Exploratory data visualisations.
# - Summary statistics describing shark attack patterns.
# - Processed dataset exported for use in the Power BI dashboard.
# - Visual outputs saved in outputs/figures.
#
#
# ## Additional Comments
#
# - The dataset contains historical records of shark attack incidents from multiple countries.
# - Personal identifiers such as victim names will be removed to ensure ethical data handling.
# - The analysis focuses on identifying patterns in time, location, activity type, and fatality outcomes.
# - Findings from this notebook will support the development of an interactive dashboard.
#
#
# ## References
#
# - Dulvy, N. K. et al. (2014). *Extinction risk and conservation of the world’s sharks and rays*. eLife.
#
# - Information Commissioner’s Office. (2023). *Guide to data protection*. ICO.
#
# - Neff, C., & Hueter, R. (2013). *Science, policy, and the public discourse of shark “attack”*. Journal of Environmental Studies and Sciences.

# %% [markdown]
# ---

# %% [markdown]
# # Change working directory

# %% [markdown]
# * We are assuming you will store the notebooks in a subfolder, therefore when running the notebook in the editor, you will need to change the working directory

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\Shazia Mujahid\\Documents\\shark-attack-project\\shark-attack-data-dashboard\\jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# 'c:\\Users\\Shazia Mujahid\\Documents\\shark-attack-project\\shark-attack-data-dashboard'

# %% [markdown]
# ---

# %% [markdown]
# # 1. Dataset Overview and Loading

# %% [markdown]
# In this section, the shark attack dataset is loaded and inspected to understand the structure. Initial checks are performed to examine the number of observations, available variables, missing values, and general dataset characteristics before moving onto the data cleaning stage. This step is crucial for identifying potential data quality issues before the data cleaning stage.

# %%
# Import libraries for data analysis and visualisation.

import pandas as pd     # Used for data manipulation and analysis
import numpy as np      # Provides numerical operations and array support
import matplotlib.pyplot as plt   # Used for creating basic visualisations
import seaborn as sns   # Built on matplotlib for improved statistical visualisations

# %%
# Load the raw shark attack dataset.

df = pd.read_csv("data/raw/shark_attacks.csv")

# Display the first few rows to preview the dataset structure

df.head()
# Out:
#          date    year        type    country                area  \
# 0  2023-05-13  2023.0  Unprovoked  AUSTRALIA     South Australia
# 1  2023-04-29  2023.0  Unprovoked  AUSTRALIA   Western Australia
# 2  2022-10-07  2022.0  Unprovoked  AUSTRALIA  Western  Australia
# 3  2021-10-04  2021.0  Unprovoked        USA             Florida
# 4  2021-10-03  2021.0  Unprovoked        USA             Florida
#
#                                    location      activity                name  \
# 0                                  Elliston       Surfing    Simon Baccanello
# 1                      Yallingup, Busselton      Swimming                male
# 2                              Port Hedland  Spearfishing         Robbie Peck
# 3  Fort Pierce State Park, St. Lucie County       Surfing  Truman Van Patrick
# 4               Jensen Beach, Martin County      Swimming                male
#
#   sex   age fatal_y_n   time      species
# 0   M    46         Y  10h10  White shark
# ...

# %%
# Examine the size of the dataset.
# This shows the total number of rows (records) and columns (variables).

df.shape
# Out:
# (6890, 13)

# %% [markdown]
# The dataset contains 6,890 recorded shark incident observations and 13 variables describing each incident. Each row represents a single shark attack record, while the columns contain information such as the date, location, activity being performed, shark species involved, and whether the incident resulted in a fatality.

# %%
# Display the column names to understand which variables are available.
# This helps identify which variables may be relevant for analysis.

df.columns
# Out:
# Index(['date', 'year', 'type', 'country', 'area', 'location', 'activity',
#        'name', 'sex', 'age', 'fatal_y_n', 'time', 'species'],
#       dtype='object')

# %% [markdown]
# The dataset contains 13 variables describing each shark incident. These variables include temporal information such as the date and year of the incident, geographic information including country and location, and contextual details such as the activity being performed and the shark species involved.
#
# The dataset also contains demographic attributes of individuals involved in the incidents and an indicator of whether the incident resulted in a fatality.

# %%
# Display dataset information including data types and non-null values.
# This helps identify missing data and potential type conversions required during cleaning.

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6890 entries, 0 to 6889
# Data columns (total 13 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       6587 non-null   object
#  1   year       6758 non-null   float64
#  2   type       6871 non-null   object
#  3   country    6839 non-null   object
#  4   area       6409 non-null   object
#  5   location   6325 non-null   object
#  6   activity   6304 non-null   object
#  7   name       6670 non-null   object
#  8   sex        6318 non-null   object
#  9   age        3903 non-null   object
#  10  fatal_y_n  6890 non-null   object
#  11  time       3372 non-null   object
#  12  species    3772 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 699.9+ KB

# %% [markdown]
# The dataset contains 6,890 observations and 13 variables describing shark incident records. Most variables are stored as object (string) data types, while the year variable is stored as a numeric value (float64).
#
# Several variables contain missing values, which will need to be addressed during the data cleaning stage. For example, the variables age, time, and species contain a large number of missing entries.
#
# The variable name contains personally identifiable information and will be removed during the cleaning process to ensure the dataset is anonymised before analysis.

# %%
# Check the number of missing values in each column.
# Missing data may require cleaning or transformation before analysis.

df.isnull().sum()
# Out:
# date          303
# year          132
# type           19
# country        51
# area          481
# location      565
# activity      586
# name          220
# sex           572
# age          2987
# fatal_y_n       0
# time         3518
# species      3118
# dtype: int64

# %% [markdown]
# The missing value analysis shows that several variables in the dataset contain incomplete information. Some variables such as type, country, and year contain relatively small numbers of missing values and can be retained with minimal cleaning.
#
# However, other variables contain substantial missing data. For example, the age, time, and species columns contain a large proportion of missing values. These variables may require careful handling or may be excluded from certain analyses depending on their completeness.
#
# As previously mentioned, the name column contains personally identifiable information and will be removed during the cleaning stage to ensure the dataset used for analysis is anonymised.

# %% [markdown]
# ---

# %% [markdown]
# # 2. Data Preparation

# %% [markdown]
# This section prepares the dataset for further analysis. Initial preparation steps are performed to ensure the dataset is suitable for cleaning and analysis.
#
# These steps include removing variables that are not required for the analysis, preparing column names for easier manipulation, and converting certain variables into more appropriate data types. Preparing the dataset in this way helps ensure consistency and improves the efficiency of subsequent data cleaning and feature engineering steps.

# %% [markdown]
# ## 2.1 Remove Personally Identifiable Information

# %% [markdown]
# The dataset contains a column labelled `name`, which includes the names of individuals involved in shark attack incidents. Since this information is not required for the analysis and represents personally identifiable information, the column is removed to maintain data privacy and ensure the dataset used for analysis is anonymised.

# %%
# Remove the 'name' column from the dataset.
# This column contains personally identifiable information (PII), which is not needed for the analysis and should be excluded to help preserve privacy and anonymise the dataset.

df = df.drop(columns=["name"])

# Display the first few rows to confirm that the column has been removed from the DataFrame.

df.head()
# Out:
#          date    year        type    country                area  \
# 0  2023-05-13  2023.0  Unprovoked  AUSTRALIA     South Australia
# 1  2023-04-29  2023.0  Unprovoked  AUSTRALIA   Western Australia
# 2  2022-10-07  2022.0  Unprovoked  AUSTRALIA  Western  Australia
# 3  2021-10-04  2021.0  Unprovoked        USA             Florida
# 4  2021-10-03  2021.0  Unprovoked        USA             Florida
#
#                                    location      activity sex   age fatal_y_n  \
# 0                                  Elliston       Surfing   M    46         Y
# 1                      Yallingup, Busselton      Swimming   M   NaN         N
# 2                              Port Hedland  Spearfishing   M    38         N
# 3  Fort Pierce State Park, St. Lucie County       Surfing   M  25.0         N
# 4               Jensen Beach, Martin County      Swimming   M   NaN         N
#
#     time      species
# 0  10h10  White shark
# 1  11h20     1m shark
# 2  11h30   Bull shark
# ...

# %% [markdown]
# ## 2.2 Standardise Column Names

# %% [markdown]
# To improve readability and ensure consistency when referencing variables in code, column names are standardised by converting them to lowercase and removing any unnecessary whitespace.

# %%
# Standardise all column names by:
# 1. converting them to lowercase
# 2. removing leading and trailing whitespace

# This makes the dataset easier to work with and reduces the risk of coding errors caused by inconsistent naming conventions.

df.columns = df.columns.str.lower().str.strip()

# Display the updated column names to verify that the formatting has been applied correctly.
df.columns
# Out:
# Index(['date', 'year', 'type', 'country', 'area', 'location', 'activity',
#        'sex', 'age', 'fatal_y_n', 'time', 'species'],
#       dtype='object')

# %% [markdown]
# ## 2.3 Convert the Year Variable

# %% [markdown]
# The `year` variable is currently stored as a floating-point data type. Since years are whole-number values, this variable is converted to numeric format to ensure consistency and support time-based analysis.

# %%
# Convert the 'year' column to a numeric data type.
# Any non-numeric values will be converted to NaN using errors='coerce'.

df["year"] = pd.to_numeric(df["year"], errors="coerce")

# Convert the column to pandas nullable integer type (Int64).
# This allows integer values while still supporting missing values.

df["year"] = df["year"].astype("Int64")

# Check the data type to confirm the conversion.

df["year"].dtype
# Out:
# Int64Dtype()

# %% [markdown]
# ## 2.4 Convert the Date Variable

# %% [markdown]
# The `date` column is converted from text format to a datetime format. This ensures the variable is suitable for chronological analysis and allows dates to be handled more efficiently in pandas.

# %%
# Convert the 'date' column to datetime format.
# Invalid or inconsistent date values will be converted to NaT (Not a Time) using errors='coerce'.

# This allows the date variable to be used for time-based analysis, filtering, and sorting.

df["date"] = pd.to_datetime(df["date"], errors="coerce")

# Display the first few values from the 'date' column to verify that the conversion was successful.

df["date"].head()
# Out:
# 0   2023-05-13
# 1   2023-04-29
# 2   2022-10-07
# 3   2021-10-04
# 4   2021-10-03
# Name: date, dtype: datetime64[ns]

# %% [markdown]
# ## 2.5 Verify Dataset Structure

# %% [markdown]
# After the initial preparation steps, the dataset structure is reviewed to confirm that the transformations have been applied correctly and that the dataset is ready for the cleaning stage.

# %%
# Display a summary of the dataset structure after preparation.
# This includes:
# - the number of rows and columns
# - column names
# - non-null counts
# - data types

# This step is used to confirm that:
# - the 'name' column has been removed
# - the 'date' column is now datetime
# - the 'year' column has been converted to numeric format

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6890 entries, 0 to 6889
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       6577 non-null   datetime64[ns]
#  1   year       6758 non-null   Int64
#  2   type       6871 non-null   object
#  3   country    6839 non-null   object
#  4   area       6409 non-null   object
#  5   location   6325 non-null   object
#  6   activity   6304 non-null   object
#  7   sex        6318 non-null   object
#  8   age        3903 non-null   object
#  9   fatal_y_n  6890 non-null   object
#  10  time       3372 non-null   object
#  11  species    3772 non-null   object
# dtypes: Int64(1), datetime64[ns](1), object(10)
# memory usage: 652.8+ KB

# %% [markdown]
# ### Section 2 Summary
#
# The dataset has now undergone initial preparation steps. Personally identifiable information has been removed, and key variables such as `date` and `year` have been formatted to support analysis.
#
# These preparation steps improve dataset consistency and ensure that the data is ready for the next stage, which focuses on cleaning missing values, resolving inconsistencies, and engineering features for analysis.

# %% [markdown]
# ---

# %% [markdown]
# # 3. Data Cleaning and Feature Engineering

# %% [markdown]
# This section focuses on cleaning the dataset and preparing variables for analysis. Real-world datasets often contain inconsistencies, missing values, and formatting issues that must be addressed before meaningful analysis can be conducted.
#
# The cleaning process includes handling missing values, standardising categorical variables, and improving the overall quality of the dataset. These steps ensure that the dataset is reliable and suitable for exploratory analysis and visualisation in later stages of the project.

# %% [markdown]
# ## 3.1 Review Missing Values
#
# Before performing cleaning operations, the dataset is re-examined to identify the extent of missing data across each variable. Understanding where missing values occur helps guide decisions on whether data should be removed, imputed, or retained depending on analytical relevance.

# %%
# Recalculate the number of missing values in each column.
# This provides an updated overview of dataset completeness before applying cleaning operations.

df.isnull().sum()
# Out:
# date          313
# year          132
# type           19
# country        51
# area          481
# location      565
# activity      586
# sex           572
# age          2987
# fatal_y_n       0
# time         3518
# species      3118
# dtype: int64

# %% [markdown]
# The missing value analysis highlights several variables with incomplete data. Some variables such as `type`, `country`, and `year` contain relatively few missing values and can be retained without significant impact on the analysis.
#
# Other variables, including `activity`, `sex`, `area`, and `location`, contain moderate levels of missing data but still provide useful contextual information about shark attack incidents.
#
# However, variables such as `age`, `time`, and `species` contain a substantial number of missing values. While these variables remain potentially valuable for analysis, missing entries will need to be considered when interpreting results.
#
# Also, the `fatal_y_n` variable contains no missing values, making it a reliable variable for analysing the outcomes of shark attack incidents.

# %% [markdown]
# ## 3.2 Remove Records Without a Year
#
# The `year` variable is critical for analysing temporal trends in shark attacks. Records that do not contain a valid year value cannot contribute to time-based analysis and are therefore removed from the dataset.

# %%
# Remove rows where the year value is missing.
# These records cannot be used for time-based analysis.

df = df.dropna(subset=["year"])

# Confirm the dataset size after removal.

df.shape
# Out:
# (6758, 12)

# %%
# Validate that there are no missing values in the 'year' column after cleaning.

df["year"].isnull().sum()
# Out:
# 0

# %% [markdown]
# Records with missing values in the `year` column were removed because the year variable is essential for analysing temporal trends in shark attack incidents.
#
# A total of 132 records were removed from the dataset, reducing the dataset from 6,890 to 6,758 observations. Removing these records ensures that all remaining entries contain valid temporal information required for time-based analysis.

# %% [markdown]
# ## 3.3 Standardise the Sex Variable
#
# The `sex` variable contains inconsistent representations of gender, such as "M", "Male", or lowercase variations. These values are standardised to ensure consistent categorisation during analysis.

# %%
# View the unique values in the sex column to understand existing variations.

df["sex"].unique()
# Out:
# array(['M', 'F', nan, 'N', '.', 'M x 2', 'lli'], dtype=object)

# %%
# Standardise the sex column by converting values to uppercase to ensure consistent formatting.

df["sex"] = df["sex"].str.upper()

# Replace invalid or ambiguous entries with NaN so that only valid categories remain.

df["sex"] = df["sex"].replace(["N", ".", "M X 2", "LLI"], np.nan)

# Check the cleaned values

df["sex"].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %% [markdown]
# The `sex` variable contained several inconsistent or invalid entries, including values such as "N", ".", and other irregular text strings. These values likely represent data entry errors or ambiguous records.
#
# To ensure consistency, the variable was standardised by converting text to uppercase and replacing invalid entries with missing values. After cleaning, the column contains only valid categories representing male (`M`) and female (`F`) individuals, with missing values where the information was unavailable.

# %% [markdown]
# ## 3.4 Clean the Age Variable
#
# The `age` column is currently stored as a text variable and may contain non-numeric values. To support quantitative analysis, the column is converted into a numeric format. Any invalid values are converted to missing values.

# %%
# Convert the age column to numeric format.
# Invalid entries will be converted to NaN using errors='coerce'.

df["age"] = pd.to_numeric(df["age"], errors="coerce")

# Verify the updated data type.

df["age"].dtype
# Out:
# dtype('float64')

# %% [markdown]
# The `age` column was originally stored as a text variable and contained non-numeric values. To support quantitative analysis, the column was converted to numeric format using `pd.to_numeric()`.
#
# Any invalid or non-numeric values were automatically converted to missing values (`NaN`). After conversion, the variable can now be used for statistical analysis and visualisation of age-related patterns in shark attack incidents.

# %% [markdown]
# ## 3.5 Inspect Activity Categories
#
# The `activity` variable describes the human activity being performed at the time of the incident. Since this field contains free-text descriptions, it may include a wide variety of values that require standardisation.

# %%
# View the most common activity values to understand the types of activities recorded.

df["activity"].value_counts().head(20)
# Out:
# activity
# Surfing            1111
# Swimming            993
# Fishing             490
# Spearfishing        381
# Wading              169
# Bathing             163
# Diving              133
# Snorkeling          126
# Standing            113
# Scuba diving         82
# Body boarding        64
# Body surfing         51
# Boogie boarding      42
# Kayaking             41
# Fell overboard       33
# Treading water       33
# Free diving          30
# Pearl diving         28
# Surf skiing          24
# Windsurfing          20
# Name: count, dtype: int64

# %%
# Create a simplified activity category variable. This groups similar activities together to make analysis easier.

df["activity_group"] = df["activity"].str.lower()

# Surfing related activities

df.loc[df["activity_group"].str.contains("surf", na=False), "activity_group"] = "surfing"


# Swimming related activities

df.loc[df["activity_group"].str.contains("swim|bathing|wading|standing|treading", na=False), "activity_group"] = "swimming"


# Fishing related activities

df.loc[df["activity_group"].str.contains("fish", na=False), "activity_group"] = "fishing"


# Diving related activities

df.loc[df["activity_group"].str.contains("div", na=False), "activity_group"] = "diving"


# Watercraft activities

df.loc[df["activity_group"].str.contains("kayak|boat|ski|wind|board", na=False), "activity_group"] = "watercraft"


# Everything else

df.loc[~df["activity_group"].isin(["surfing","swimming","fishing","diving","watercraft"]), "activity_group"] = "other"


# Check the new grouped categories

df["activity_group"].value_counts()
# Out:
# activity_group
# swimming      1745
# surfing       1417
# other         1404
# fishing       1243
# diving         514
# watercraft     435
# Name: count, dtype: int64

# %%
# Validate that the new activity group variable has been created correctly by displaying the original and new columns side by side for the first few records.

df[["activity", "activity_group"]].head(10)
# Out:
#        activity activity_group
# 0       Surfing        surfing
# 1      Swimming       swimming
# 2  Spearfishing        fishing
# 3       Surfing        surfing
# 4      Swimming       swimming
# 5      Swimming       swimming
# 6       Surfing        surfing
# 7  Spearfishing        fishing
# 8           NaN          other
# 9      Swimming       swimming

# %% [markdown]
# The `activity` variable contained a large number of unique free-text descriptions describing human activities at the time of the incident. Many of these entries referred to similar activities but were recorded using different wording.
#
# To simplify the analysis and improve interpretability, activities were grouped into broader categories including swimming, surfing, fishing, diving, and watercraft-related activities. Any remaining activities that did not fit into these categories were classified as "other".
#
# This grouping reduces the number of activity categories and allows clearer comparisons when analysing patterns in shark attack incidents.

# %% [markdown]
# ## 3.6 Inspect Shark Species
#
# The `species` variable identifies the shark species involved in each incident. However, this field contains many variations and descriptive entries. Examining the most common values helps determine whether grouping or simplification may be required.

# %%
# Display the most common shark species entries to identify inconsistencies or variations.

df["species"].value_counts().head(20)
# Out:
# species
# White shark                                           191
# Shark involvement prior to death was not confirmed    105
# Invalid                                               101
# Shark involvement not confirmed                        92
# Tiger shark                                            86
# Shark involvement prior to death unconfirmed           68
# Bull shark                                             62
# 4' shark                                               43
# 6' shark                                               42
# 1.8 m [6'] shark                                       35
# Questionable incident                                  35
# Questionable                                           33
# 1.5 m [5'] shark                                       32
# 5' shark                                               29
# Wobbegong shark                                        28
# 4' to 5' shark                                         27
# ...

# %%
# Create a lowercase version of the species column to make text matching easier.

df["species_group"] = df["species"].str.lower()


# Identify major species

df.loc[df["species_group"].str.contains("white", na=False), "species_group"] = "white shark"
df.loc[df["species_group"].str.contains("tiger", na=False), "species_group"] = "tiger shark"
df.loc[df["species_group"].str.contains("bull", na=False), "species_group"] = "bull shark"


# All other entries containing the word "shark" are grouped as "other shark"

df.loc[df["species_group"].str.contains("shark", na=False), "species_group"] = "other shark"


# Assign the major species again (so they are not overwritten)

df.loc[df["species"].str.contains("White", na=False), "species_group"] = "white shark"
df.loc[df["species"].str.contains("Tiger", na=False), "species_group"] = "tiger shark"
df.loc[df["species"].str.contains("Bull", na=False), "species_group"] = "bull shark"


# Replace missing or uncertain values

df.loc[df["species_group"].isna(), "species_group"] = "unknown"


# Check the grouped results

df["species_group"].value_counts()
# Out:
# species_group
# unknown                                                                                                                                                          3024
# other shark                                                                                                                                                      2589
# white shark                                                                                                                                                       491
# tiger shark                                                                                                                                                       263
# bull shark                                                                                                                                                        157
# ...

# %%
# Replace invalid or uncertain species labels with "unknown"

df["species_group"] = df["species_group"].replace([
    "invalid",
    "questionable incident",
    "questionable",
    "unidentified species",
    "unidentified"
], "unknown")


# Check the cleaned results again

df["species_group"].value_counts()
# Out:
# species_group
# unknown                                                                                                                                                          3207
# other shark                                                                                                                                                      2589
# white shark                                                                                                                                                       491
# tiger shark                                                                                                                                                       263
# bull shark                                                                                                                                                        157
# ...

# %%
# Define the allowed species categories

major_species = ["white shark", "tiger shark", "bull shark", "other shark", "unknown"]


# Any value not in the major species list will be grouped as "other shark"

df.loc[~df["species_group"].isin(major_species), "species_group"] = "other shark"


# Check the final result

df["species_group"].value_counts()
# Out:
# species_group
# unknown        3207
# other shark    2640
# white shark     491
# tiger shark     263
# bull shark      157
# Name: count, dtype: int64

# %% [markdown]
# The `species` column contained numerous inconsistent entries including size descriptions, uncertain identifications, and free-text incident notes. To improve interpretability, the variable was simplified by grouping shark species into broader categories.
#
# Major species such as white sharks, tiger sharks, and bull sharks were retained as separate categories due to their frequency in the dataset. All other shark-related entries were grouped under "other shark", while records without confirmed shark identification were classified as "unknown".
#
# As a result, this approach reduces the complexity of the species variable and allows clearer comparisons in subsequent analysis and visualisations.

# %% [markdown]
# ## 3.7 Verify Dataset After Cleaning
#
# After applying initial cleaning steps, the dataset structure is reviewed to confirm that transformations have been applied successfully and that the dataset is ready for exploratory analysis.

# %%
# Review the structure of the cleaned dataset.

# The info() function displays the number of rows, columns, non-null counts, and data types for each variable.
# This step confirms that the previous cleaning operations (such as removing rows, converting data types, and creating new variables) were applied successfully.

df.info()


# Display the first few rows of the dataset to visually confirm that the cleaned variables (such as activity_group and species_group) have been created correctly and that the dataset appears consistent.

df.head()


# Recalculate the number of missing values in each column. This final check helps verify that missing values have been handled appropriately and highlights any remaining incomplete variables that may need to be considered during analysis.

df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6758 entries, 0 to 6884
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            6575 non-null   datetime64[ns]
#  1   year            6758 non-null   Int64
#  2   type            6742 non-null   object
#  3   country         6712 non-null   object
#  4   area            6305 non-null   object
#  5   location        6230 non-null   object
#  6   activity        6194 non-null   object
#  7   sex             6190 non-null   object
#  8   age             3763 non-null   float64
#  9   fatal_y_n       6758 non-null   object
#  10  time            3365 non-null   object
#  11  species         3735 non-null   object
#  12  activity_group  6758 non-null   object
#  13  species_group   6758 non-null   object
# dtypes: Int64(1), datetime64[ns](1), float64(1), object(11)
# memory usage: 798.6+ KB
# date               183
# year                 0
# ...

# %% [markdown]
# The cleaned dataset was reviewed to verify that all transformations were applied correctly. The dataset now contains 6758 observations and 14 variables, including newly created variables for grouped activity types and shark species.
#
# Key variables such as `year`, `activity_group`, and `species_group` are now complete and suitable for analysis. While some variables such as `age`, `time`, and `species` still contain missing values, these variables are not critical for all analyses and can still provide useful insights where data is available.
#
# Overall, this validation step confirms that the dataset has been successfully cleaned and prepared for exploratory data analysis.

# %% [markdown]
# ## 3.8 Standardising Fatality Outcome Variable
#
# The `fatal_y_n` variable indicates whether a shark attack incident resulted in a fatality. However, the dataset contains several inconsistent or unclear values such as lowercase letters, unknown outcomes, and irregular entries.
#
# To ensure reliable analysis, the variable is standardised so that only two valid categories remain:
# - **Y** – Fatal incident
# - **N** – Non-fatal incident
#
# Other values are treated as missing data and excluded from fatality analysis.

# %%
# Standardise the fatal_y_n variable by converting all values to uppercase.
# This ensures consistency for values such as 'y' or 'n'.

df["fatal_y_n"] = df["fatal_y_n"].str.upper()


# Replace unclear or invalid values with NaN so that they do not affect analysis.

df["fatal_y_n"] = df["fatal_y_n"].replace(
    ["UNKNOWN", "F", "NQ", "Y X 2", "2017.0"], np.nan
)


# Verify the cleaned fatality categories.

df["fatal_y_n"].value_counts()
# Out:
# fatal_y_n
# N    4739
# Y    1387
# Name: count, dtype: int64

# %% [markdown]
# ### Section 3 Summary
#
# This section focused on cleaning and preparing the dataset to ensure it is suitable for analysis. Several preprocessing steps were performed, including removing records without valid year values, standardising categorical variables, converting age values to numeric format, and grouping complex variables such as activity type and shark species into broader analytical categories.
#
# In addition, the fatality outcome variable was standardised to ensure consistent classification of fatal and non-fatal incidents. This step removed irregular and ambiguous entries so that the variable could be used reliably in later analysis.
#
# These transformations reduced inconsistencies within the dataset and simplified variables that originally contained numerous free-text entries. As a result, the dataset is now more structured and easier to interpret.
#
# The cleaned dataset has been validated to confirm that variables are correctly formatted and that key analytical fields are complete. With the data preparation and cleaning stages complete, the dataset is now ready for exploratory data analysis to identify patterns and trends in shark attack incidents.

# %% [markdown]
# ---

# %% [markdown]
# # 4. Exploratory Data Analysis

# %% [markdown]
# This section explores patterns within the cleaned shark attack dataset using descriptive statistics and visualisations. The goal of exploratory data analysis (EDA) is to identify trends, relationships, and distributions within the data before applying statistical tests.
#
# The analysis focuses on key variables including the year of incidents, geographic distribution, human activity at the time of the incident, shark species involvement, and fatality outcomes.

# %% [markdown]
# ## 4.1 Descriptive Statistics Overview
#
# Before examining specific patterns in shark attack incidents, descriptive statistics are used to summarise the main characteristics of the dataset.
#
# Both numerical and categorical variables are examined to provide an overview of the distribution of values within the dataset.

# %%
# Generate descriptive statistics for numerical variables.
# This provides summary statistics such as the count, mean,standard deviation, minimum, and maximum values.

df.describe()
# Out:
#                                 date         year          age
# count                           6575       6758.0  3763.000000
# mean   1973-07-29 07:37:57.171102656  1970.935928    27.969439
# min              1703-03-26 00:00:00          1.0     1.000000
# 25%              1951-10-13 12:00:00       1950.0    17.000000
# 50%              1988-02-15 00:00:00       1986.0    24.000000
# 75%              2009-09-01 12:00:00       2009.0    36.000000
# max              2023-08-16 00:00:00       2023.0    87.000000
# std                              NaN    56.227881    14.481849

# %% [markdown]
# The numerical descriptive statistics summarise key characteristics of the dataset related to time and demographic information. The dataset spans a long historical period, with recorded shark attack incidents ranging from the early eighteenth century to recent years. However, earlier records are relatively sparse and may be less reliable due to inconsistent reporting practices.
#
# The average year of recorded incidents is approximately 1971, while the median year is 1986. This indicates that a large proportion of recorded shark attacks occur in more recent decades, reflecting improved global reporting and increased participation in ocean recreational activities.
#
# The age statistics show that the average age of individuals involved in shark attacks is approximately 28 years, with a median age of 24. This suggests that younger individuals may appear more frequently in recorded incidents, potentially due to higher participation in water-based recreational activities such as swimming and surfing.
#
# Overall, these numerical statistics provide an initial overview of the dataset and highlight variables that will be examined further in the subsequent exploratory analyses.

# %%
# Generate descriptive statistics for categorical variables.
# This summarises the number of unique values, the most frequent category, and its frequency.

df.describe(include="object")
# Out:
#               type country     area                          location  \
# count         6742    6712     6305                              6230
# unique          11     209      841                              4367
# top     Unprovoked     USA  Florida  New Smyrna Beach, Volusia County
# freq          4954    2505     1166                               192
#
#        activity   sex fatal_y_n       time      species activity_group  \
# count      6194  6190      6126       3365         3735           6758
# unique     1513     2         2        397         1548              6
# top     Surfing     M         N  Afternoon  White shark       swimming
# freq       1111  5435      4739        211          191           1745
#
#        species_group
# count           6758
# unique             5
# top          unknown
# freq            3207

# %% [markdown]
# The categorical descriptive statistics provide an overview of key contextual variables within the shark attack dataset. The dataset contains incidents recorded across 209 different countries, indicating that shark–human interactions occur globally. The United States appears as the most frequently recorded country, accounting for the largest number of incidents in the dataset. Within the United States, Florida is the most commonly reported region.
#
# The majority of incidents are classified as **unprovoked**, suggesting that most shark attacks occur without deliberate human interaction with sharks. Surfing and swimming appear frequently among recorded activities, reflecting the high level of participation in these ocean-based recreational activities.
#
# The dataset also shows that the majority of individuals involved in shark attacks are male. In terms of outcomes, non-fatal incidents are substantially more common than fatal ones.
#
# The engineered variables created during the data cleaning stage provide simplified categories for analysis. The `activity_group` variable consolidates many specific activities into six broader groups, while the `species_group` variable categorises shark species into five major groups. These grouped variables improve interpretability and support clearer visualisations in the subsequent exploratory analysis.

# %% [markdown]
# ## 4.2 Shark Attack Incidents Over Time
#
# To investigate temporal trends in shark attack incidents, the number of recorded attacks is aggregated by year. This allows us to observe whether shark attack incidents have increased, decreased, or remained stable over time.

# %%
# Calculate the number of shark attack incidents recorded each year.
# The value_counts() function counts how many times each year appears in the dataset, representing the number of incidents in that year.

# The results are then sorted by year using sort_index() so that the data appears in chronological order, which is necessary for time series visualisation.

attacks_per_year = df["year"].value_counts().sort_index()

# Display the first few values to verify that the yearly counts have been calculated correctly.

attacks_per_year.head()
# Out:
# year
# 1       1
# 1000    1
# 1500    1
# 1518    1
# 1543    1
# Name: count, dtype: Int64

# %%
# Filter the dataset to include only incidents recorded from 1900 onwards.
# Earlier records are often incomplete or inconsistent and may distort the visualisation of modern shark attack trends.

df_modern = df[df["year"] >= 1900]

# Recalculate yearly shark attack counts using the filtered dataset.

attacks_per_year = df_modern["year"].value_counts().sort_index()

# Display the first few rows to verify the filtered data.

attacks_per_year.head()
# Out:
# year
# 1900    13
# 1901     9
# 1902    15
# 1903    10
# 1904    14
# Name: count, dtype: Int64

# %%
# Create a line chart to visualise how the number of shark attack incidents has changed over time using the filtered dataset.

# Set the figure size to make the chart easier to read.
plt.figure(figsize=(12,6))


# Plot the yearly incident counts as a line chart.
# Each point on the line represents the total number of shark attack incidents recorded in that year.

attacks_per_year.plot()


# Add a descriptive title explaining what the chart shows.

plt.title("Number of Shark Attack Incidents Over Time (1900–Present)")


# Label the horizontal axis to indicate the year of incidents.

plt.xlabel("Year")


# Label the vertical axis to indicate the number of incidents.

plt.ylabel("Number of Incidents")

# Plot the yearly counts with a thicker line for clarity

attacks_per_year.plot(linewidth=2)

plt.title("Number of Shark Attack Incidents Over Time (1900–Present)")
plt.xlabel("Year")
plt.ylabel("Number of Incidents")


# Add gridlines to improve readability

plt.grid(alpha=0.3)

plt.tight_layout()


# Display the chart.

plt.show()

# %% [markdown]
# The line chart shows the number of recorded shark attack incidents per year from 1900 onwards. Records prior to 1900 were excluded from the analysis because historical reporting during that period is incomplete and may distort modern trends.
#
# The visualisation suggests that the number of recorded shark attacks has generally increased over time. In the early twentieth century, annual incident counts were relatively low and stable. From the mid-twentieth century onwards, the number of reported incidents begins to increase, with a noticeable rise from the 1990s onwards. In recent decades, several years show more than 100 recorded incidents.
#
# This increase does not necessarily indicate that sharks are becoming more aggressive. Instead, it is likely influenced by factors such as population growth in coastal areas, increased participation in ocean recreational activities such as surfing and swimming, improved reporting systems, and more comprehensive global data collection.
#
# Despite the upward trend in reported incidents, shark attacks remain rare events relative to the millions of people who enter the ocean each year.

# %% [markdown]
# ## 4.3 Human Activities Associated with Shark Attacks
#
# To understand which human activities are most commonly associated with shark attack incidents, the distribution of incidents across different activity categories is analysed.
#
# The dataset previously grouped similar activities into broader categories (activity_group) to simplify the analysis and improve interpretability. Examining these categories helps identify which ocean activities are most frequently involved in recorded shark attack incidents.

# %%
# Calculate the number of shark attack incidents for each activity group.
# The value_counts() function counts how many incidents occurred for each activity category.

activity_counts = df["activity_group"].value_counts()

# Display the activity distribution to verify the counts.

activity_counts
# Out:
# activity_group
# swimming      1745
# surfing       1417
# other         1404
# fishing       1243
# diving         514
# watercraft     435
# Name: count, dtype: int64

# %%
# Create a bar chart to visualise the number of shark attack incidents associated with each activity category.

plt.figure(figsize=(10,6))


# Plot the activity counts as a bar chart.

activity_counts.plot(kind="bar")


# Add a descriptive title.

plt.title("Shark Attack Incidents by Human Activity")


# Label the axes.

plt.xlabel("Activity Type")
plt.ylabel("Number of Incidents")


# Improve readability with gridlines.

plt.grid(axis="y", alpha=0.3)

plt.tight_layout()

# Display the chart.

plt.show()

# %% [markdown]
# The bar chart shows the number of recorded shark attack incidents associated with different human activity categories. The results indicate that swimming and surfing account for the largest proportion of incidents in the dataset.
#
# These activities involve individuals spending extended periods at or near the ocean surface, which may increase the likelihood of encounters with sharks. In contrast, activities such as diving and watercraft use show relatively fewer recorded incidents.
#
# Fishing activities also account for a substantial number of incidents. This may be influenced by the presence of bait, caught fish, or fishing equipment in the water, which can attract sharks to the surrounding area.
#
# It is important to note that higher incident counts for certain activities may also reflect the popularity of those activities. Swimming and surfing are among the most common recreational ocean activities worldwide, which naturally increases the probability that shark–human interactions occur during these activities.
#
# These results suggest that the type of human activity may influence the likelihood of shark attack incidents, which will be explored further in later analysis examining the relationship between activity type and fatality outcomes.

# %% [markdown]
# ## 4.4 Fatal vs Non-Fatal Shark Attacks
#
# To understand the severity of shark attack incidents, the distribution of fatal and non-fatal outcomes is analysed. The dataset includes a variable (`fatal_y_n`) indicating whether an incident resulted in a fatality.
#
# Examining this distribution helps determine whether fatal shark attacks represent a significant proportion of total recorded incidents.

# %%
# Calculate the number of fatal and non-fatal shark attack incidents.
# The value_counts() function counts the frequency of each category within the cleaned fatal_y_n variable.

fatal_counts = df["fatal_y_n"].value_counts()


# Rename the index values to make the chart labels easier to read.

fatal_counts.index = ["Non-Fatal", "Fatal"]


# Display the counts to verify the distribution before plotting.

fatal_counts
# Out:
# Non-Fatal    4739
# Fatal        1387
# Name: count, dtype: int64

# %%
# Create a bar chart to visualise the distribution of fatal and non-fatal shark attack incidents.

plt.figure(figsize=(8,5))


# Plot the fatality counts as a bar chart.

fatal_counts.plot(kind="bar")


# Add a descriptive title to explain the chart.

plt.title("Fatal vs Non-Fatal Shark Attack Incidents")


# Label the axes for clarity.

plt.xlabel("Outcome")
plt.ylabel("Number of Incidents")


# Add light gridlines to improve readability.

plt.grid(axis="y", alpha=0.3)


# Adjust layout to ensure labels and title fit neatly.

plt.tight_layout()


# Display the completed chart.

plt.show()

# %% [markdown]
# The bar chart shows the distribution of fatal and non-fatal shark attack incidents in the dataset. The results indicate that the majority of shark attacks are non-fatal, accounting for a substantially larger proportion of recorded incidents. Fatal attacks represent a much smaller share of the total cases.
#
# Although shark attacks often receive significant media attention due to their perceived danger, the data suggests that most encounters do not result in fatalities. Improvements in emergency response, medical treatment, and increased public awareness of ocean safety may contribute to higher survival rates following shark encounters.
#
# These findings support the hypothesis that non-fatal shark attacks occur more frequently than fatal incidents.
#
# Overall, the results highlight that while shark attacks are serious events, they are relatively rare and are more likely to result in survival than fatality.
